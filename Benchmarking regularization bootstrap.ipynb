# %%
import pandas as pd
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv',  na_values
                 =['NA','?'])

#generate dummie for job
df = pd.concat([df, pd.get_dummies
                (df['job'], prefix='job')], axis=1)
df.drop('job', axis=1, inplace = True)

#generate dummies for area
df = pd.concat([df, pd.get_dummies(df['area'], prefix='area')], axis=1)
df.drop('area', axis=1, inplace=True)

#generate dummies for products
df = pd.concat([df, pd.get_dummies(
                df['product'], prefix='product')], axis=1)
df.drop('product', axis=1, inplace=True)

#missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

#standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['subscriptions'] = zscore(df['subscriptions'])

#convert to numpy -classification
x_columns = df.columns.drop('age').drop('id')
x = df[x_columns].values
y = df['age'].values

# %% [markdown]
# the following code perform the bootstrap. The architecture of the neural network can be adjusted to
# compare many different configurations

# %%
import os
import numpy as np
import time
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import ShuffleSplit

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
SPLITS=50

#bootstrap
boot = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=42)

#track progress
mean_benchmark = []
epochs_needed = []
num = 0

#loop through samples
for train, test in boot.split(x):
    start_time = time.time()
    num+=1
    
    #split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]
    
    #construct neural network
    model = Sequential()
    model.add(Dense(20, input_dim=x_train.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    
    monitor = EarlyStopping(monitor = 'val_loss', min_delta=1e-3,
                           patience=5, verbose=0, mode='auto', restore_best_weights=True)
    # train on the bootstrap sample
    model.fit(x_train, y_train, validation_data=(x_test, y_test), callbacks=[monitor],verbose=0, epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    #predict on the out of boot (validation)
    pred = model.predict(x_test)
    
    
    #measure this bootstrap's log loss
    score = np.sqrt(metrics.mean_squared_error(pred, y_test))
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}, stdev={mdev:.6f},epochs={epochs}, mean epochs={int(m2)},  time={hms_string(time_took)}")
# Out:
# #1: score=0.693469, mean score=0.693469, stdev=0.000000,epochs=101, mean epochs=101,  time=0:00:16.77
# #2: score=0.741775, mean score=0.717622, stdev=0.024153,epochs=121, mean epochs=111,  time=0:00:20.29
# #3: score=0.792233, mean score=0.742492, stdev=0.040323,epochs=139, mean epochs=120,  time=0:00:22.07
# #4: score=0.758366, mean score=0.746461, stdev=0.035591,epochs=134, mean epochs=123,  time=0:00:21.33
# #5: score=0.725727, mean score=0.742314, stdev=0.032896,epochs=131, mean epochs=125,  time=0:00:21.03
# #6: score=1.142235, mean score=0.808967, stdev=0.152037,epochs=135, mean epochs=126,  time=0:00:21.84
# #7: score=0.659789, mean score=0.787656, stdev=0.150127,epochs=93, mean epochs=122,  time=0:00:14.90
# #8: score=0.556555, mean score=0.758769, stdev=0.159882,epochs=113, mean epochs=120,  time=0:00:18.69
# #9: score=0.693585, mean score=0.751526, stdev=0.152124,epochs=127, mean epochs=121,  time=0:00:20.66
# #10: score=1.166042, mean score=0.792978, stdev=0.190504,epochs=78, mean epochs=117,  time=0:00:12.70
# #11: score=1.005641, mean score=0.812311, stdev=0.191651,epochs=74, mean epochs=113,  time=0:00:12.40
# #12: score=0.601329, mean score=0.794729, stdev=0.192534,epochs=152, mean epochs=116,  time=0:00:24.23
# #13: score=0.579896, mean score=0.778203, stdev=0.193637,epochs=112, mean epochs=116,  time=0:00:18.67
# #14: score=1.232790, mean score=0.810674, stdev=0.220280,epochs=78, mean epochs=113,  time=0:00:12.78
# #15: score=0.634740, mean score=0.798945, stdev=0.217289,epochs=137, mean epochs=115,  time=0:00:22.46
# #16: score=0.881792, mean score=0.804123, stdev=0.211342,epochs=124, mean epochs=115,  time=0:00:19.99
# #17: score=0.652337, mean score=0.795194, stdev=0.208119,epochs=157, mean epochs=118,  time=0:00:24.80
# #18: score=1.060331, mean score=0.809924, stdev=0.211177,epochs=96, mean epochs=116,  time=0:00:15.67
# #19: score=0.611638, mean score=0.799488, stdev=0.210260,epochs=101, mean epochs=115,  time=0:00:16.32
# #20: score=0.700893, mean score=0.794558, stdev=0.206059,epochs=146, mean epochs=117,  time=0:00:23.36
# #21: score=0.828845, mean score=0.796191, stdev=0.201226,epochs=107, mean epochs=116,  time=0:00:17.45
# #22: score=0.553431, mean score=0.785156, stdev=0.202998,epochs=99, mean epochs=116,  time=0:00:16.69
# #23: score=0.583783, mean score=0.776401, stdev=0.202739,epochs=119, mean epochs=116,  time=0:00:19.01
# #24: score=0.678309, mean score=0.772314, stdev=0.199436,epochs=103, mean epochs=115,  time=0:00:16.28
# #25: score=0.689279, mean score=0.768992, stdev=0.196083,epochs=122, mean epochs=115,  time=0:00:19.65
# #26: score=0.675341, mean score=0.765390, stdev=0.193116,epochs=99, mean epochs=115,  time=0:00:15.90
# #27: score=0.602131, mean score=0.759344, stdev=0.191998,epochs=122, mean epochs=115,  time=0:00:19.45
# #28: score=0.717544, mean score=0.757851, stdev=0.188698,epochs=146, mean epochs=116,  time=0:00:23.78
# #29: score=0.571311, mean score=0.751419, stdev=0.188514,epochs=127, mean epochs=117,  time=0:00:20.79
# #30: score=0.589820, mean score=0.746032, stdev=0.187602,epochs=125, mean epochs=117,  time=0:00:19.95
# #31: score=0.845426, mean score=0.749238, stdev=0.185385,epochs=95, mean epochs=116,  time=0:00:15.33
# #32: score=0.660712, mean score=0.746472, stdev=0.183114,epochs=120, mean epochs=116,  time=0:00:19.48
# #33: score=0.597810, mean score=0.741967, stdev=0.182110,epochs=126, mean epochs=116,  time=0:00:19.99
# #34: score=1.201573, mean score=0.755485, stdev=0.195497,epochs=115, mean epochs=116,  time=0:00:18.14
# #35: score=0.592151, mean score=0.750818, stdev=0.194595,epochs=98, mean epochs=116,  time=0:00:16.45
# #36: score=0.619249, mean score=0.747163, stdev=0.193088,epochs=96, mean epochs=115,  time=0:00:15.41
# #37: score=1.056446, mean score=0.755522, stdev=0.196954,epochs=102, mean epochs=115,  time=0:00:16.71
# #38: score=0.664750, mean score=0.753134, stdev=0.194887,epochs=128, mean epochs=115,  time=0:00:20.67
# #39: score=0.490404, mean score=0.746397, stdev=0.196804,epochs=150, mean epochs=116,  time=0:00:24.09
# #40: score=0.741355, mean score=0.746271, stdev=0.194330,epochs=129, mean epochs=116,  time=0:00:20.68
# #41: score=1.263060, mean score=0.758875, stdev=0.207841,epochs=95, mean epochs=116,  time=0:00:15.46
# #42: score=0.655694, mean score=0.756419, stdev=0.205954,epochs=103, mean epochs=116,  time=0:00:16.75
# #43: score=0.668446, mean score=0.754373, stdev=0.203976,epochs=112, mean epochs=115,  time=0:00:18.25
# #44: score=0.590884, mean score=0.750657, stdev=0.203112,epochs=123, mean epochs=116,  time=0:00:20.23
# #45: score=1.154816, mean score=0.759639, stdev=0.209492,epochs=94, mean epochs=115,  time=0:00:15.61
# #46: score=0.518287, mean score=0.754392, stdev=0.210170,epochs=134, mean epochs=116,  time=0:00:21.47
# #47: score=0.630172, mean score=0.751749, stdev=0.208694,epochs=98, mean epochs=115,  time=0:00:15.93
# #48: score=0.697160, mean score=0.750611, stdev=0.206656,epochs=93, mean epochs=115,  time=0:00:15.29
# #49: score=1.070264, mean score=0.757135, stdev=0.209470,epochs=115, mean epochs=115,  time=0:00:18.95
# #50: score=0.689177, mean score=0.755776, stdev=0.207583,epochs=158, mean epochs=116,  time=0:00:25.36

# %% [markdown]
# # bootstrapping for classification

# %% [markdown]
# regression bootstrapping uses the **StratifiedShuffleSplit** object to perform the splits. This is similar to StratifiedKFold
# for cross validation,as the classes are balanced so that the sampling has no effect on propotions. To demonstrate this technique
# we will attempt to predict the prodcut column for simple dataset this data is loaded below

# %%
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])
# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %%
x_train.shape
# Out:
# (1800, 47)

# %%
y.shape
# Out:
# (2000, 7)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit

SPLITS = 50

# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1, 
                                random_state=42)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
    model.add(Dense(25, activation='relu')) # Hidden 2
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=25, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test),
              callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}," +\
          f"stdev={mdev:.6f}, epochs={epochs}, mean epochs={int(m2)}," +\
          f" time={hms_string(time_took)}")
# Out:
# #1: score=0.662159, mean score=0.662159,stdev=0.000000, epochs=78, mean epochs=78, time=0:00:12.41
# #2: score=0.662452, mean score=0.662306,stdev=0.000146, epochs=65, mean epochs=71, time=0:00:09.51
# #3: score=0.671561, mean score=0.665391,stdev=0.004365, epochs=56, mean epochs=66, time=0:00:07.59
# #4: score=0.656017, mean score=0.663048,stdev=0.005546, epochs=78, mean epochs=69, time=0:00:10.26
# #5: score=0.657234, mean score=0.661885,stdev=0.005479, epochs=97, mean epochs=74, time=0:00:12.85
# #6: score=0.690042, mean score=0.666578,stdev=0.011625, epochs=55, mean epochs=71, time=0:00:07.80
# #7: score=0.713074, mean score=0.673220,stdev=0.019508, epochs=52, mean epochs=68, time=0:00:07.20
# #8: score=0.766360, mean score=0.684863,stdev=0.035802, epochs=51, mean epochs=66, time=0:00:07.02
# #9: score=0.627125, mean score=0.678447,stdev=0.038323, epochs=56, mean epochs=65, time=0:00:07.64
# #10: score=0.641238, mean score=0.674726,stdev=0.038031, epochs=99, mean epochs=68, time=0:00:13.02
# #11: score=0.688514, mean score=0.675980,stdev=0.036477, epochs=84, mean epochs=70, time=0:00:10.99
# #12: score=0.700752, mean score=0.678044,stdev=0.035589, epochs=71, mean epochs=70, time=0:00:09.53
# #13: score=0.695077, mean score=0.679354,stdev=0.034493, epochs=95, mean epochs=72, time=0:00:12.67
# #14: score=0.720023, mean score=0.682259,stdev=0.034849, epochs=48, mean epochs=70, time=0:00:06.67
# #15: score=0.640262, mean score=0.679459,stdev=0.035260, epochs=77, mean epochs=70, time=0:00:10.54
# #16: score=0.718783, mean score=0.681917,stdev=0.035442, epochs=77, mean epochs=71, time=0:00:10.47
# #17: score=0.660172, mean score=0.680638,stdev=0.034763, epochs=68, mean epochs=71, time=0:00:09.16
# #18: score=0.694424, mean score=0.681404,stdev=0.033931, epochs=63, mean epochs=70, time=0:00:08.71
# #19: score=0.603496, mean score=0.677303,stdev=0.037327, epochs=59, mean epochs=69, time=0:00:07.98
# #20: score=0.709001, mean score=0.678888,stdev=0.037032, epochs=47, mean epochs=68, time=0:00:06.61
# #21: score=0.648973, mean score=0.677464,stdev=0.036697, epochs=51, mean epochs=67, time=0:00:06.88
# #22: score=0.727022, mean score=0.679716,stdev=0.037310, epochs=64, mean epochs=67, time=0:00:08.54
# #23: score=0.575813, mean score=0.675199,stdev=0.042196, epochs=79, mean epochs=68, time=0:00:10.82
# #24: score=0.720281, mean score=0.677077,stdev=0.042278, epochs=66, mean epochs=68, time=0:00:08.64
# #25: score=0.588007, mean score=0.673514,stdev=0.044951, epochs=77, mean epochs=68, time=0:00:10.34
# #26: score=0.661324, mean score=0.673046,stdev=0.044140, epochs=73, mean epochs=68, time=0:00:09.80
# #27: score=0.690629, mean score=0.673697,stdev=0.043442, epochs=87, mean epochs=69, time=0:00:11.59
# #28: score=0.710696, mean score=0.675018,stdev=0.043209, epochs=88, mean epochs=70, time=0:00:11.76
# #29: score=0.669892, mean score=0.674841,stdev=0.042467, epochs=62, mean epochs=69, time=0:00:08.21
# #30: score=0.710128, mean score=0.676018,stdev=0.042231, epochs=92, mean epochs=70, time=0:00:11.98
# #31: score=0.709898, mean score=0.677111,stdev=0.041974, epochs=54, mean epochs=69, time=0:00:07.53
# #32: score=0.672468, mean score=0.676966,stdev=0.041321, epochs=86, mean epochs=70, time=0:00:11.47
# #33: score=0.623864, mean score=0.675356,stdev=0.041695, epochs=62, mean epochs=70, time=0:00:08.64
# #34: score=0.576468, mean score=0.672448,stdev=0.044346, epochs=94, mean epochs=70, time=0:00:12.44
# #35: score=0.501321, mean score=0.667559,stdev=0.052184, epochs=91, mean epochs=71, time=0:00:12.18
# #36: score=0.648058, mean score=0.667017,stdev=0.051553, epochs=49, mean epochs=70, time=0:00:06.65
# #37: score=0.635529, mean score=0.666166,stdev=0.051108, epochs=48, mean epochs=70, time=0:00:06.71
# #38: score=0.684873, mean score=0.666658,stdev=0.050520, epochs=73, mean epochs=70, time=0:00:09.66
# #39: score=0.762233, mean score=0.669109,stdev=0.052106, epochs=51, mean epochs=69, time=0:00:07.02
# #40: score=0.712927, mean score=0.670204,stdev=0.051903, epochs=48, mean epochs=69, time=0:00:06.70
# #41: score=0.745519, mean score=0.672041,stdev=0.052566, epochs=39, mean epochs=68, time=0:00:05.47
# #42: score=0.668011, mean score=0.671945,stdev=0.051940, epochs=45, mean epochs=67, time=0:00:06.16
# #43: score=0.703265, mean score=0.672674,stdev=0.051549, epochs=49, mean epochs=67, time=0:00:06.74
# #44: score=0.765818, mean score=0.674790,stdev=0.052817, epochs=67, mean epochs=67, time=0:00:09.15
# #45: score=0.654120, mean score=0.674331,stdev=0.052316, epochs=69, mean epochs=67, time=0:00:09.52
# #46: score=0.673185, mean score=0.674306,stdev=0.051744, epochs=52, mean epochs=67, time=0:00:07.24
# #47: score=0.690253, mean score=0.674646,stdev=0.051242, epochs=51, mean epochs=66, time=0:00:06.97
# #48: score=0.733692, mean score=0.675876,stdev=0.051402, epochs=89, mean epochs=67, time=0:00:11.69
# #49: score=0.654793, mean score=0.675445,stdev=0.050962, epochs=64, mean epochs=67, time=0:00:08.64
# #50: score=0.656319, mean score=0.675063,stdev=0.050521, epochs=58, mean epochs=67, time=0:00:07.69

# %% [markdown]
# #  benchmarking

# %% [markdown]
# now that we've seen how to bootstrap with both classification and regression we can start to try to optimize the hyperparameters for the simple dataset data. For this example we willencode for classficiation of the product column. Evaluation will be log loss

# %%
import pandas as pd
from scipy.stats import zscore

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],
               axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %% [markdown]
# I performed some optimization and the code is currently set to the best setting that i came up with. Later, we can use an automatic process to optimize the hyperparameters

# %%
import pandas as pd
import os
import numpy as np
import time
import tensorflow.keras.initializers
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.layers import LeakyReLU,PReLU

SPLITS = 100

# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(100, input_dim=x.shape[1], activation=PReLU(), \
        kernel_regularizer=regularizers.l2(1e-4))) # Hidden 1
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), \
        activity_regularizer=regularizers.l2(1e-4))) # Hidden 2
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), \
        activity_regularizer=regularizers.l2(1e-4)
    )) # Hidden 3
#    model.add(Dropout(0.5)) - Usually better performance 
# without dropout on final layer
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=100, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test), \
              callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}," +\
          f"stdev={mdev:.6f}, epochs={epochs}, mean epochs={int(m2)}," +\
          f" time={hms_string(time_took)}")
# Out:
# #1: score=0.626487, mean score=0.626487,stdev=0.000000, epochs=230, mean epochs=230, time=0:00:57.87
# #2: score=0.585000, mean score=0.605743,stdev=0.020743, epochs=491, mean epochs=360, time=0:01:58.10
# #3: score=0.644065, mean score=0.618517,stdev=0.024763, epochs=174, mean epochs=298, time=0:00:40.58
# #4: score=0.627637, mean score=0.620797,stdev=0.021806, epochs=221, mean epochs=279, time=0:00:50.85
# #5: score=0.632618, mean score=0.623161,stdev=0.020069, epochs=199, mean epochs=263, time=0:00:46.38
# #6: score=0.599026, mean score=0.619139,stdev=0.020409, epochs=164, mean epochs=246, time=0:00:40.31
# #7: score=0.640858, mean score=0.622241,stdev=0.020366, epochs=170, mean epochs=235, time=0:00:39.81
# #8: score=0.685518, mean score=0.630151,stdev=0.028300, epochs=277, mean epochs=240, time=0:01:03.92
# #9: score=0.651465, mean score=0.632519,stdev=0.027509, epochs=156, mean epochs=231, time=0:00:36.41
# #10: score=0.698371, mean score=0.639104,stdev=0.032732, epochs=140, mean epochs=222, time=0:00:32.73
# #11: score=0.547951, mean score=0.630818,stdev=0.040751, epochs=214, mean epochs=221, time=0:00:49.49
# #12: score=0.755690, mean score=0.641224,stdev=0.052090, epochs=187, mean epochs=218, time=0:00:43.21
# #13: score=0.673786, mean score=0.643729,stdev=0.050793, epochs=155, mean epochs=213, time=0:00:36.17
# #14: score=0.630729, mean score=0.642800,stdev=0.049060, epochs=210, mean epochs=213, time=0:00:47.99
# #15: score=0.756854, mean score=0.650404,stdev=0.055280, epochs=125, mean epochs=207, time=0:00:29.68
# #16: score=0.702688, mean score=0.653671,stdev=0.055000, epochs=134, mean epochs=202, time=0:00:31.59
# #17: score=0.679933, mean score=0.655216,stdev=0.053715, epochs=197, mean epochs=202, time=0:00:45.46
# #18: score=0.631177, mean score=0.653881,stdev=0.052491, epochs=149, mean epochs=199, time=0:00:35.13
# #19: score=0.749481, mean score=0.658912,stdev=0.055371, epochs=194, mean epochs=199, time=0:00:44.41
# #20: score=0.673844, mean score=0.659659,stdev=0.054067, epochs=147, mean epochs=196, time=0:00:34.48
# #21: score=0.597217, mean score=0.656685,stdev=0.054414, epochs=310, mean epochs=202, time=0:01:11.14
# #22: score=0.535931, mean score=0.651197,stdev=0.058813, epochs=222, mean epochs=203, time=0:00:51.93
# #23: score=0.591453, mean score=0.648599,stdev=0.058797, epochs=177, mean epochs=201, time=0:00:41.23
# #24: score=0.623248, mean score=0.647543,stdev=0.057781, epochs=208, mean epochs=202, time=0:00:48.01
# #25: score=0.683207, mean score=0.648969,stdev=0.057043, epochs=151, mean epochs=200, time=0:00:35.25
# #26: score=0.757931, mean score=0.653160,stdev=0.059732, epochs=124, mean epochs=197, time=0:00:28.96
# #27: score=0.731140, mean score=0.656048,stdev=0.060437, epochs=142, mean epochs=195, time=0:00:32.88
# #28: score=0.683641, mean score=0.657034,stdev=0.059568, epochs=142, mean epochs=193, time=0:00:32.98
# #29: score=0.623100, mean score=0.655864,stdev=0.058859, epochs=260, mean epochs=195, time=0:00:59.51
# #30: score=0.677684, mean score=0.656591,stdev=0.058002, epochs=171, mean epochs=194, time=0:00:39.73
# #31: score=0.670208, mean score=0.657030,stdev=0.057109, epochs=165, mean epochs=193, time=0:00:38.30
# #32: score=0.624476, mean score=0.656013,stdev=0.056495, epochs=241, mean epochs=195, time=0:00:55.33
# #33: score=0.595303, mean score=0.654173,stdev=0.056597, epochs=197, mean epochs=195, time=0:00:45.66
# #34: score=0.662322, mean score=0.654413,stdev=0.055776, epochs=192, mean epochs=195, time=0:00:44.40
# #35: score=0.658260, mean score=0.654523,stdev=0.054977, epochs=208, mean epochs=195, time=0:00:47.72
# #36: score=0.625580, mean score=0.653719,stdev=0.054416, epochs=205, mean epochs=195, time=0:00:46.95
# #37: score=0.659979, mean score=0.653888,stdev=0.053685, epochs=279, mean epochs=198, time=0:01:03.59
# #38: score=0.654547, mean score=0.653905,stdev=0.052974, epochs=164, mean epochs=197, time=0:00:38.37
# #39: score=0.658461, mean score=0.654022,stdev=0.052296, epochs=218, mean epochs=197, time=0:00:50.45
# #40: score=0.624826, mean score=0.653292,stdev=0.051839, epochs=220, mean epochs=198, time=0:00:50.47
# #41: score=0.734239, mean score=0.655267,stdev=0.052703, epochs=148, mean epochs=197, time=0:00:34.61
# #42: score=0.669033, mean score=0.655594,stdev=0.052114, epochs=186, mean epochs=196, time=0:00:42.99
# #43: score=0.574949, mean score=0.653719,stdev=0.052919, epochs=320, mean epochs=199, time=0:01:13.51
# #44: score=0.533012, mean score=0.650976,stdev=0.055321, epochs=261, mean epochs=201, time=0:00:59.94
# #45: score=0.638962, mean score=0.650709,stdev=0.054732, epochs=151, mean epochs=199, time=0:00:34.80
# #46: score=0.643400, mean score=0.650550,stdev=0.054144, epochs=265, mean epochs=201, time=0:01:00.57
# #47: score=0.677612, mean score=0.651125,stdev=0.053707, epochs=141, mean epochs=200, time=0:00:32.63
# #48: score=0.668107, mean score=0.651479,stdev=0.053200, epochs=167, mean epochs=199, time=0:00:38.55
# #49: score=0.692206, mean score=0.652310,stdev=0.052968, epochs=166, mean epochs=198, time=0:00:38.16
# #50: score=0.651735, mean score=0.652299,stdev=0.052436, epochs=238, mean epochs=199, time=0:00:54.63
# #51: score=0.720438, mean score=0.653635,stdev=0.052772, epochs=215, mean epochs=199, time=1:50:17.26
# #52: score=0.626914, mean score=0.653121,stdev=0.052391, epochs=303, mean epochs=201, time=0:01:11.08
# #53: score=0.673701, mean score=0.653509,stdev=0.051970, epochs=170, mean epochs=201, time=0:00:40.72
# #54: score=0.676370, mean score=0.653933,stdev=0.051578, epochs=144, mean epochs=200, time=0:00:33.64
# #55: score=0.539595, mean score=0.651854,stdev=0.053342, epochs=223, mean epochs=200, time=0:00:51.96
# #56: score=0.589855, mean score=0.650747,stdev=0.053497, epochs=200, mean epochs=200, time=0:00:46.10
# #57: score=0.658599, mean score=0.650885,stdev=0.053036, epochs=162, mean epochs=199, time=0:00:37.36
# #58: score=0.695937, mean score=0.651661,stdev=0.052903, epochs=171, mean epochs=199, time=0:00:40.57
# #59: score=0.694956, mean score=0.652395,stdev=0.052749, epochs=161, mean epochs=198, time=0:00:38.05
# #60: score=0.638328, mean score=0.652161,stdev=0.052339, epochs=161, mean epochs=198, time=0:00:37.25
# #61: score=0.694963, mean score=0.652862,stdev=0.052192, epochs=180, mean epochs=197, time=0:00:41.80
# #62: score=0.747777, mean score=0.654393,stdev=0.053132, epochs=182, mean epochs=197, time=0:00:41.87
# #63: score=0.669927, mean score=0.654640,stdev=0.052744, epochs=187, mean epochs=197, time=0:00:43.29
# #64: score=0.635809, mean score=0.654346,stdev=0.052383, epochs=188, mean epochs=197, time=0:00:43.35
# #65: score=0.728768, mean score=0.655491,stdev=0.052779, epochs=129, mean epochs=196, time=0:00:30.49
# #66: score=0.691157, mean score=0.656031,stdev=0.052559, epochs=156, mean epochs=195, time=0:00:36.13
# #67: score=0.672260, mean score=0.656273,stdev=0.052202, epochs=211, mean epochs=195, time=0:00:49.03
# #68: score=0.753655, mean score=0.657705,stdev=0.053126, epochs=189, mean epochs=195, time=0:00:43.46
# #69: score=0.731329, mean score=0.658772,stdev=0.053469, epochs=181, mean epochs=195, time=0:00:41.44
# #70: score=0.685496, mean score=0.659154,stdev=0.053180, epochs=159, mean epochs=194, time=0:00:36.69
# #71: score=0.659841, mean score=0.659164,stdev=0.052804, epochs=163, mean epochs=194, time=0:00:38.19
# #72: score=0.739165, mean score=0.660275,stdev=0.053266, epochs=157, mean epochs=193, time=0:00:36.42
# #73: score=0.695093, mean score=0.660752,stdev=0.053054, epochs=163, mean epochs=193, time=0:00:37.99
# #74: score=0.603944, mean score=0.659984,stdev=0.053101, epochs=206, mean epochs=193, time=0:00:47.78
# #75: score=0.668307, mean score=0.660095,stdev=0.052754, epochs=169, mean epochs=193, time=0:00:39.29
# #76: score=0.673592, mean score=0.660273,stdev=0.052429, epochs=159, mean epochs=192, time=0:00:37.39
# #77: score=0.663520, mean score=0.660315,stdev=0.052088, epochs=217, mean epochs=193, time=0:00:49.99
# #78: score=0.698059, mean score=0.660799,stdev=0.051927, epochs=142, mean epochs=192, time=0:00:32.83
# #79: score=0.666326, mean score=0.660869,stdev=0.051601, epochs=203, mean epochs=192, time=0:00:47.67
# #80: score=0.753591, mean score=0.662028,stdev=0.052302, epochs=146, mean epochs=192, time=0:00:34.41
# #81: score=0.721509, mean score=0.662762,stdev=0.052392, epochs=181, mean epochs=191, time=0:00:43.10
# #82: score=0.640171, mean score=0.662487,stdev=0.052130, epochs=184, mean epochs=191, time=0:00:46.74
# #83: score=0.627748, mean score=0.662068,stdev=0.051954, epochs=177, mean epochs=191, time=0:01:10.98
# #84: score=0.640439, mean score=0.661811,stdev=0.051697, epochs=227, mean epochs=192, time=0:01:53.10
# #85: score=0.720661, mean score=0.662503,stdev=0.051782, epochs=133, mean epochs=191, time=0:01:06.45
# #86: score=0.660071, mean score=0.662475,stdev=0.051481, epochs=214, mean epochs=191, time=0:01:35.99
# #87: score=0.680771, mean score=0.662685,stdev=0.051221, epochs=181, mean epochs=191, time=0:01:21.17
# #88: score=0.658859, mean score=0.662641,stdev=0.050931, epochs=127, mean epochs=190, time=0:00:57.88
# #89: score=0.697581, mean score=0.663034,stdev=0.050778, epochs=193, mean epochs=190, time=0:01:27.27
# #90: score=0.629913, mean score=0.662666,stdev=0.050614, epochs=185, mean epochs=190, time=0:01:23.69
# #91: score=0.681532, mean score=0.662873,stdev=0.050374, epochs=173, mean epochs=190, time=0:01:18.60
# #92: score=0.635118, mean score=0.662572,stdev=0.050182, epochs=213, mean epochs=190, time=0:01:35.87
# #93: score=0.628943, mean score=0.662210,stdev=0.050032, epochs=202, mean epochs=190, time=0:01:31.21
# #94: score=0.595127, mean score=0.661496,stdev=0.050239, epochs=191, mean epochs=190, time=0:01:21.10
# #95: score=0.678756, mean score=0.661678,stdev=0.050004, epochs=194, mean epochs=191, time=0:01:23.11
# #96: score=0.730329, mean score=0.662393,stdev=0.050229, epochs=201, mean epochs=191, time=0:01:24.57
# #97: score=0.701607, mean score=0.662797,stdev=0.050126, epochs=202, mean epochs=191, time=0:01:27.28
# #98: score=0.655841, mean score=0.662726,stdev=0.049875, epochs=139, mean epochs=190, time=0:00:56.89
# #99: score=0.631417, mean score=0.662410,stdev=0.049721, epochs=241, mean epochs=191, time=0:01:40.84
# #100: score=0.650443, mean score=0.662291,stdev=0.049486, epochs=212, mean epochs=191, time=0:01:34.78
